# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidT0Dev/Analytics/blob/main/InstaColorSentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install instaloader
# !pip install matplotlib
# !pip install pandas
# !pip install scikit-learn

# %%
import instaloader
L = instaloader.Instaloader()
username = input("Username:")
profile = instaloader.Profile.from_username(L.context, username)
# Out:
# Username:DazzlingDreamrs

# %%
for post in profile.get_posts():
    # Save image
    L.download_post(post, target=profile.username)
    # Collect comments
    # ...
# Out:
# dazzlingdreamrs/2023-05-16_13-49-04_UTC.jpg exists [Getting lost is easy, and fin…] unchanged json
# dazzlingdreamrs/2023-05-09_13-20-14_UTC.jpg exists [It's never too late to rememb…] unchanged json
# dazzlingdreamrs/2023-05-31_13-09-56_UTC.jpg exists [They would love to help aroun…] unchanged json
# dazzlingdreamrs/2023-05-30_13-18-25_UTC.jpg exists [Dream big and don't fear leav…] unchanged json
# dazzlingdreamrs/2023-05-29_13-12-44_UTC.jpg exists [Stopping to recharge is not o…] unchanged json
# dazzlingdreamrs/2023-05-12_13-35-52_UTC.jpg exists [If it can be lost, it can be …] unchanged json
# dazzlingdreamrs/2023-05-08_01-10-31_UTC.jpg exists ["Go confidently in the direct…] unchanged json
# dazzlingdreamrs/2023-05-04_22-30-32_UTC.jpg exists [Willy the robo-whale on his w…] unchanged json
# dazzlingdreamrs/2023-04-26_12-20-45_UTC.jpg exists [Skydiving bobsleigh is better…] unchanged json
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./' + username + '/2011-09-24_13-04-15_UTC.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>
